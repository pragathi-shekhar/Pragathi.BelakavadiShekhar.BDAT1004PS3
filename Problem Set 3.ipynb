# %% [markdown]
# # Problem set 3

# %% [markdown]
# # Question 1

# %%
#Step 1,2 and 3

import pandas as pd
users = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep='|',index_col=False)
users.set_index('user_id')
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
#Q1. Step 4 - Mean age per occupation

users.groupby('occupation').mean()
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %%
#Q1. Step 5 - Male ratio per occupation and sort it from the most to the least

ratio = users.groupby('occupation')['gender'].value_counts(normalize=True)
ratio.sort_values(ascending=False)
# Out:
# occupation     gender
# doctor         M         1.000000
# engineer       M         0.970149
# technician     M         0.962963
# retired        M         0.928571
# programmer     M         0.909091
# executive      M         0.906250
# scientist      M         0.903226
# entertainment  M         0.888889
# homemaker      F         0.857143
# lawyer         M         0.833333
# salesman       M         0.750000
# educator       M         0.726316
# student        M         0.693878
# healthcare     F         0.687500
# other          M         0.657143
# marketing      M         0.615385
# writer         M         0.577778
# librarian      F         0.568627
# none           M         0.555556
# administrator  M         0.544304
# artist         M         0.535714
#                F         0.464286
# administrator  F         0.455696
# none           F         0.444444
# librarian      M         0.431373
# writer         F         0.422222
# marketing      F         0.384615
# ...

# %%
#Q1. step 6 - Maximum age for each occupation

users.groupby('occupation').age.agg([min,max])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#Q1. step 7 - Mean age for each occupation and gender

users.groupby(['occupation','gender']).mean()
# Out:
#                          user_id        age
# occupation    gender
# administrator F       443.944444  40.638889
#               M       420.069767  37.162791
# artist        F       432.153846  30.307692
#               M       469.000000  32.333333
# doctor        M       533.714286  43.571429
# educator      F       454.730769  39.115385
#               M       471.492754  43.101449
# engineer      F       806.500000  29.500000
#               M       445.553846  36.600000
# entertainment F       780.000000  31.000000
#               M       350.250000  29.000000
# executive     F       373.000000  44.000000
#               M       427.413793  38.172414
# healthcare    F       568.454545  39.818182
#               M       354.000000  45.400000
# homemaker     F       367.166667  34.166667
#               M       898.000000  23.000000
# lawyer        F       285.000000  39.500000
#               M       373.900000  36.200000
# librarian     F       449.137931  40.000000
# ...

# %%
#Q1 step 8 - percentage of men and women for each occupation

(users.groupby(['occupation','gender']).count()/users.groupby('occupation').count())*100
# Out:
#                              age  gender     user_id    zip_code
# occupation    gender
# administrator F        45.569620     NaN   45.569620   45.569620
#               M        54.430380     NaN   54.430380   54.430380
# artist        F        46.428571     NaN   46.428571   46.428571
#               M        53.571429     NaN   53.571429   53.571429
# doctor        M       100.000000     NaN  100.000000  100.000000
# educator      F        27.368421     NaN   27.368421   27.368421
#               M        72.631579     NaN   72.631579   72.631579
# engineer      F         2.985075     NaN    2.985075    2.985075
#               M        97.014925     NaN   97.014925   97.014925
# entertainment F        11.111111     NaN   11.111111   11.111111
#               M        88.888889     NaN   88.888889   88.888889
# executive     F         9.375000     NaN    9.375000    9.375000
#               M        90.625000     NaN   90.625000   90.625000
# ...

# %% [markdown]
# # Question 2

# %%
#Q2 Step 1, 2 and 3  

import pandas as pd
euro12 = pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12.set_index('Team')
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Q2 step 4  

euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#Q2 step 5 - Number of teams  

len(euro12['Team'])
# Out:
# 16

# %%
#Q2 step 6 - count of columns  

len(euro12.columns)
# Out:
# 35

# %%
#Q2 step 7 - View columns Team, Yellow Cards and Red Cards  

discipline = pd.DataFrame(euro12,columns=['Team','Red Cards','Yellow Cards'])
discipline.set_index('Team')
# Out:
#                      Red Cards  Yellow Cards
# Team
# Croatia                      0             9
# Czech Republic               0             7
# Denmark                      0             4
# England                      0             5
# France                       0             6
# Germany                      0             4
# Greece                       1             9
# Italy                        0            16
# Netherlands                  0             5
# Poland                       1             7
# Portugal                     0            12
# Republic of Ireland          1             6
# Russia                       0             6
# Spain                        0            11
# Sweden                       0             7
# Ukraine                      0             5

# %%
# Q2 step 8 - Sort by Red card 

discipline.sort_values(by='Red Cards',ascending=False)
# Out:
#                    Team  Red Cards  Yellow Cards
# 6                Greece          1             9
# 9                Poland          1             7
# 11  Republic of Ireland          1             6
# 0               Croatia          0             9
# 1        Czech Republic          0             7
# 2               Denmark          0             4
# 3               England          0             5
# 4                France          0             6
# 5               Germany          0             4
# 7                 Italy          0            16
# 8           Netherlands          0             5
# 10             Portugal          0            12
# 12               Russia          0             6
# 13                Spain          0            11
# 14               Sweden          0             7
# 15              Ukraine          0             5

# %%
# Q2 step 8 - Sort by Yellow card

discipline.sort_values(by='Yellow Cards',ascending=False)
# Out:
#                    Team  Red Cards  Yellow Cards
# 7                 Italy          0            16
# 10             Portugal          0            12
# 13                Spain          0            11
# 0               Croatia          0             9
# 6                Greece          1             9
# 1        Czech Republic          0             7
# 9                Poland          1             7
# 14               Sweden          0             7
# 4                France          0             6
# 11  Republic of Ireland          1             6
# 12               Russia          0             6
# 3               England          0             5
# 8           Netherlands          0             5
# 15              Ukraine          0             5
# 2               Denmark          0             4
# 5               Germany          0             4

# %%
#Q2 step 9 - mean Yellow Cards given per Team

discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#Q2 step 10 - Teams with Goals more than 6

euro12[euro12['Goals']>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#Q2 step 11 - Teams with starting letter G

startsWithG = euro12.loc[euro12['Team'].str.startswith('G')]
startsWithG
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#Q2 step 12 - First 7 columns

euro12.iloc[ : , 0:7]
euro12
# Out:
#      Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0   False      4               13                12             51.9%
# 1   False      4               13                18             41.9%
# 2   False      4               10                10             50.0%
# 3   False      5               11                18             50.0%
# 4   False      3               22                24             37.9%
# 5    True     10               32                32             47.8%
# 6   False      5                8                18             30.7%
# 7   False      6               34                45             43.0%
# 8   False      2               12                36             25.0%
# 9   False      2               15                23             39.4%
# 10  False      6               22                42             34.3%
# 11  False      1                7                12             36.8%
# ...

# %%
#Q2 step 13 - All columns except last 3

euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Q2 step 14 - Shooting accuracy from England, Italy and Russia

rows=['England','Italy','Russia']
col = ['Shooting Accuracy']
euro12.set_index('Team').loc[rows,col]
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %% [markdown]
# # Question 3

# %%
#Q3 Step 1,2

import numpy as np
series1 = np.linspace(1,4,100)
series2 = np.linspace(1,3,100)
series3 = np.linspace(10000,30000,100)
print(series1)

# %%
#Q3 step 3,4

priceDataframe = pd.DataFrame({'bedrs':series1, 'bathrs': series2, 'price_sqr_meter':series3})
priceDataframe
# Out:
#        bedrs    bathrs  price_sqr_meter
# 0   1.000000  1.000000     10000.000000
# 1   1.030303  1.020202     10202.020202
# 2   1.060606  1.040404     10404.040404
# 3   1.090909  1.060606     10606.060606
# 4   1.121212  1.080808     10808.080808
# ..       ...       ...              ...
# 95  3.878788  2.919192     29191.919192
# 96  3.909091  2.939394     29393.939394
# 97  3.939394  2.959596     29595.959596
# 98  3.969697  2.979798     29797.979798
# 99  4.000000  3.000000     30000.000000
#
# [100 rows x 3 columns]

# %%
#Q3 step 5,6,7

series = np.append(series1,[series2,series3])
bigcolumn = pd.DataFrame({'bigColumn':series})
bigcolumn
# Out:
#         bigColumn
# 0        1.000000
# 1        1.030303
# 2        1.060606
# 3        1.090909
# 4        1.121212
# ..            ...
# 295  29191.919192
# 296  29393.939394
# 297  29595.959596
# 298  29797.979798
# 299  30000.000000
#
# [300 rows x 1 columns]

# %% [markdown]
# # Question 4

# %%
# Q4 step 1, 2 and 3

import pandas as pd
import datetime
data = pd.read_csv(r'wind.txt',sep='\s+',index_col=False,parse_dates = {'Date':['Yr','Mo','Dy']})
data.head()
# Out:
#         Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
#Q4 step 4

def correct_year(val):
    year = val.year - 100  if val.year>2018 else val.year
    return datetime.date(year, val.month, val.day)
    
data['Date'] = data['Date'].apply(correct_year)
data
# Out:
#             Date    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
#Q4 Step5

data = data.set_index('Date')
data.index.astype('datetime64[ns]')
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %%
#Q4 step 6 - missing values count

print(data.iloc[1:].isnull().sum())
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    1
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
#Q4 step 7 - non-missing values count

print(data.count().sum())
# Out:
# 78857

# %%
#Q4 step 8 - mean windspeeds of the windspeeds over all the locations and

mean_windspeed = data.mean()
mean_windspeed.mean()
# Out:
# 10.227982360836924

# %%
#Q4 step 9 

loc_stats = data.agg(['min','max','mean','std'])
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %%
#Q4 step 10

day_stats = pd.DataFrame()

day_stats['min'] = data.min(axis=1)
day_stats['max'] = data.max(axis = 1) 
day_stats['mean'] = data.mean(axis = 1) 
day_stats['std'] = data.std(axis = 1) 
day_stats
# Out:
#              min    max       mean       std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %%
#Q4 step 11

data.index.astype('datetime64[ns]')
#print([pd.DatetimeIndex(data['Date']).month])

#print(data['Date'].dt.month)
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %%
#Q4 step 12 

yearly = data.resample('A').mean()
yearly
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1972-12-31  12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# 1973-12-31  11.828466  10.680493  10.680493  5.547863   9.640877  6.548740
# 1974-12-31  13.643096  11.811781  12.336356  6.427041  11.110986  6.809781
# 1975-12-31  12.008575  10.293836  11.564712  5.269096   9.190082  5.668521
# 1976-12-31  11.737842  10.203115  10.761230  5.109426   8.846339  6.311038
# ...               ...        ...        ...       ...        ...       ...
# 2067-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 2068-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 2069-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 2070-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 2071-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
#
# ...

# %%
#Q4 step 13

monthly = data.resample('M').mean()
monthly
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1972-01-31  14.383871  11.848387  13.732258  5.925161  10.823226  7.291290
# 1972-02-29  14.046207  10.814483  12.960000  6.347586  10.918621  7.245172
# 1972-03-31  12.900000  10.505161  13.220323  6.949032  10.996452  6.949677
# 1972-04-30  13.675333  10.638000  13.237667  7.232667  11.253667  7.036333
# 1972-05-31  15.963226  12.636129  14.579355  7.974839  13.021290  7.560968
# ...               ...        ...        ...       ...        ...       ...
# 2071-08-31   9.783226   6.991935  10.227097  4.540968   8.978065  4.797742
# 2071-09-30   8.365000   6.512667   7.704333  3.470667   7.676667  5.462667
# 2071-10-31  12.926129  11.106452  12.467419  5.778065  11.305161  8.562903
# 2071-11-30  13.334667  10.853667  12.223333  6.250667  10.895000  7.660000
# 2071-12-31  13.162581  10.606774  13.367097  6.070000  10.393871  7.841613
#
# ...

# %%
#Q4 step 14

weekly = data.resample('W').mean()
weekly
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1972-01-02   9.125000   2.545000  13.270000   4.375000   4.980000   2.625000
# 1972-01-09  11.792857   7.761429  11.124286   4.212857   7.742857   5.500000
# 1972-01-16  17.061429  14.494286  16.241429   7.025714  12.231429   8.808571
# 1972-01-23  13.291429  13.375714  10.905714   5.304286  11.874286   8.457143
# 1972-01-30  15.732857  12.928571  16.025714   7.304286  11.665714   6.702857
# ...               ...        ...        ...        ...        ...        ...
# 2071-12-06   9.432857   8.880000   7.755714   2.404286   7.097143   4.291429
# 2071-12-13   9.471429   6.048571   8.330000   3.791429   7.065714   5.614286
# 2071-12-20  21.120000  18.934286  17.741429  10.798571  16.771429  13.542857
# 2071-12-27  12.938571  10.191429  12.685714   5.910000  10.054286   8.178571
# 2072-01-03  13.397500   9.127500  24.280000   7.960000  11.657500   6.872500
#
# ...

# %%
#Q4 step 15

weekly = data.resample('W').agg(['min','max','mean','std'])
weekly
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Date
# 1972-01-02   8.96   9.29   9.125000  0.233345   1.46   3.63   2.545000
# 1972-01-09   6.83  17.00  11.792857  3.557915   0.67  13.92   7.761429
# 1972-01-16   8.63  23.96  17.061429  6.596682   4.58  20.62  14.494286
# 1972-01-23   7.21  20.41  13.291429  5.470854   7.29  18.71  13.375714
# 1972-01-30  11.25  26.42  15.732857  6.172797   7.25  19.12  12.928571
# ...           ...    ...        ...       ...    ...    ...        ...
# 2071-12-06   3.33  16.29   9.432857  5.111646   4.04  16.08   8.880000
# 2071-12-13   4.67  16.33   9.471429  4.740216   0.42  12.75   6.048571
# 2071-12-20  17.00  26.50  21.120000  3.548089  15.83  23.54  18.934286
# 2071-12-27   7.58  22.08  12.938571  5.692552   5.09  15.96  10.191429
# 2072-01-03  12.42  14.88  13.397500  1.049266   6.34  10.50   9.127500
#
# ...

# %% [markdown]
# # Question 5

# %%
#step 1,2 and 3

import pandas as pd
chipo = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Q5 step 4

chipo.iloc[0:10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Q5 step 5 - number of observations in the dataset

len(chipo)
# Out:
# 4622

# %%
#Q5 step 6 - the number of columns in the dataset

len(chipo.columns)
# Out:
# 5

# %%
#Q5 step7 - List column names

chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Q5 step 8 - How is dataset indexed

chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Q5 step 9 - Most ordered item and it's count

chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
#Q5 step 10 - For the most-ordered item, how many items were ordered?
chipo.groupby('item_name').count().sort_values(by='quantity',ascending=False)
# Out:
#                                        order_id  quantity  choice_description  \
# item_name
# Chicken Bowl                                726       726                 726
# Chicken Burrito                             553       553                 553
# Chips and Guacamole                         479       479                   0
# Steak Burrito                               368       368                 368
# Canned Soft Drink                           301       301                 301
# Steak Bowl                                  211       211                 211
# Chips                                       211       211                   0
# Bottled Water                               162       162                   0
# Chicken Soft Tacos                          115       115                 115
# Chicken Salad Bowl                          110       110                 110
# Chips and Fresh Tomato Salsa                110       110                   0
# ...

# %%
#Q5 step 11 - Most ordered item in the choice_description column

chipo.groupby('choice_description').count().sort_values(by='quantity',ascending=False)
# Out:
#                                                     order_id  quantity  \
# choice_description
# [Diet Coke]                                              134       134
# [Coke]                                                   123       123
# [Sprite]                                                  77        77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        42        42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        40        40
# ...                                                      ...       ...
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...         1         1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...         1         1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...         1         1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...         1         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1         1
#
#                                                     item_name  item_price
# choice_description
# ...

# %%
#Q5 step 12 - Total items ordered

chipo['quantity'].sum()
# Out:
# 4972

# %%
#Q5 step 13

#convert item price to float
chipo['item_price'] =chipo.item_price.str.replace('$', '').astype(float)
chipo
# Out:
# C:\Users\PRAGAT~2\AppData\Local\Temp/ipykernel_936/3419500814.py:3: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
#Q5 step 13 

#check item price type
print("1. Data type of Item price ",chipo['item_price'].dtype)

#lambda function to change type of item price
print("2. Change data type from float to string ",chipo['item_price'].apply(lambda x: str(x) if isinstance(x, float) else x ))

#check item price type
print("3. Data type of Item price ",chipo['item_price'].dtype )
# Out:
# 1. Data type of Item price  float64
# 2. Change data type from float to string  0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object
# 3. Data type of Item price  float64

# %%
#Q5 step 14 - what is revenue for the period in the dataset

(chipo['item_price'] * chipo['quantity']).sum()
# Out:
# 39237.02

# %%
#Q5 step 15 - how many orders were made 

chipo['order_id'].nunique()
# Out:
# 1834

# %%
#Q5 step 16 average revenue amount per order

chipo['totalOrderAmount'] = chipo['item_price'] * chipo['quantity']
print("average amount per order",chipo.groupby('order_id')['totalOrderAmount'].sum().mean())
# Out:
# average amount per order 21.394231188658654

# %%
#Q5 step 17 - Number of different items sold

chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# # Question 6

# %%
#Q6 - number of marriages and divorces per capita

import pandas as pd #import pandas
marriage_divorce = pd.read_csv('us-marriages-divorces-1867-2014.csv') #read csv into dataframe 

# get columns to plot
columns = marriage_divorce.columns.drop(['Marriages_per_1000','Divorces_per_1000','Population','Year'])
# create x data
x_data = marriage_divorce['Year']
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, marriage_divorce[column])
# set title and legend
ax.set_title('Marriage vs Divorces between 1864 and 2014 in U.S')
ax.legend(columns)

# %% [markdown]
# # Question 7

# %%
#Q7 - Marriages and Divorces per capita in US

import pandas as pd #import pandas
import matplotlib.pyplot as plt 

marriage_divorce = pd.read_csv('us-marriages-divorces-1867-2014.csv') #read csv into dataframe 

marriage_divorce = marriage_divorce[marriage_divorce['Year'].apply(lambda x: x in [1900, 1950, 2000])] #apply filter on year
data = pd.DataFrame(marriage_divorce, columns=["Marriages_per_1000","Divorces_per_1000","Year"])
 
# plot the dataframe
data.plot(x="Year", y=["Marriages_per_1000","Divorces_per_1000"], kind="bar", figsize=(9, 8))
 
# print bar graph
plt.show()

# %% [markdown]
# # Question 8

# %%
#Q8 - actor kill count

import pandas as pd #import pandas
import matplotlib.pyplot as plt
actor_kill_count = pd.read_csv('actor_kill_counts.csv')#read csv into dataframe 

plt.barh(actor_kill_count['Actor'],actor_kill_count['Count'].sort_values())
plt.title('Actor Kill count')
plt.xlabel('Count')
plt.ylabel('Actor')
plt.plot(figsize=(10, 9))
plt.show()

# %%
import sys
sys.prefix
# Out:
# 'C:\\Users\\PragathiPC\\anaconda3'

# %%
! {sys.prefix}/Scripts/pip install plotly

# %% [markdown]
# # Question 9

# %%
#Q9 -Roman emperor death reasons 

import pandas as pd #import pandas

roman_emperor = pd.read_csv('roman-emperor-reigns.csv')#read csv into dataframe 
colors = ['plum','coral','lightpink','peachpuff','orange','gray','paleturquoise','mediumseagreen']#color palette
roman_emperor.groupby(['Cause_of_Death']).count().plot(kind='pie',y='Emperor',figsize=(10,10),autopct='%.0f%%',colors=colors,title="Fraction of Roman emperor assasinated vs others")
# Out:
# <AxesSubplot:title={'center':'Fraction of Roman emperor assasinated vs others'}, ylabel='Emperor'>

# %% [markdown]
# # Question 10

# %%
#Q10 - CS PhDs vs revenue by arcades

import pandas as pd #import pandas
import seaborn as sns #import seaborn

revenue_CSDoctrate = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')#read csv into dataframe

#set size of chart
fig = plt.gcf()
fig.set_size_inches(9, 8)

sns.scatterplot(x='Computer Science Doctorates Awarded (US)', y='Total Arcade Revenue (billions)', hue='Year', data=revenue_CSDoctrate).set(title='Arcade revenue vs CS Doctrate')
# Out:
# [Text(0.5, 1.0, 'Arcade revenue vs CS Doctrate')]
